# %%
from SimSiam.fedfastsiam.client import *
from SimSiam.fedfastsiam.datapreparation import *
from SimSiam.fedfastsiam.server import *
from torch.utils.data import Subset

# %%
def load_data_iid(trainset, num_clients, batch_size):
    shuffled_indices = torch.randperm(len(trainset))
    # Get the total number of indices
    num_indices = len(shuffled_indices)

    # Determine the number of indices per client
    indices_per_client = num_indices // num_clients

    # Distribute indices among clients
    local_dataloaders = []
    for i in range(num_clients):
        start = i * indices_per_client
        if i == num_clients - 1:  # Last client gets remaining indices
            end = num_indices
        else:
            end = start + indices_per_client
        client_indices = shuffled_indices[start:end]

        # create subset of dataset
        subset = Subset(trainset, client_indices)
        # create dataloader 
        local_dataloder = torch.utils.data.DataLoader(subset, batch_size=batch_size)

        local_dataloaders.append(local_dataloder)
    return local_dataloaders

# %%
def create_datasets(num_clients, dataset_size=5_000, batch_size=64, num_views=4):
    """Split the whole dataset in IID or non-IID manner for distributing to clients."""
    augmentation = [
        transforms.RandomResizedCrop(224, scale=(0.2, 1.)),
        transforms.RandomApply([
            transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)  # not strengthened
        ], p=0.8),
        transforms.RandomGrayscale(p=0.2),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        #normalize
    ]
    #train_set, val_set = torch.utils.data.random_split(trainset, [45000, 5000])
    trainset = ZenseactDataset(dataset_size, transform=TwoCropsTransform(transforms.Compose(augmentation), num_views))

    local_dataloaders = load_data_iid(trainset, num_clients, batch_size)

    return local_dataloaders

# %%
local_dataloaders = create_datasets(5)
local_dataloaders
# Out:
# [<torch.utils.data.dataloader.DataLoader at 0x7f0e08389e70>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f0e0893e800>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f0e0893ce50>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f0ee33e1f90>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f0e0808fd00>]

# %%
trainset = ZenseactDataset(5000)
num_clients=5
batch_size=32

shuffled_indices = torch.randperm(len(trainset))
print(shuffled_indices)
    # Get the total number of indices
num_indices = len(shuffled_indices)

# Determine the number of indices per client
indices_per_client = num_indices // num_clients

# Distribute indices among clients
local_dataloaders = []
for i in range(num_clients):
    start = i * indices_per_client
    if i == num_clients - 1:  # Last client gets remaining indices
        end = num_indices
    else:
        end = start + indices_per_client
    client_indices = shuffled_indices[start:end]

    # create subset of dataset
    subset = Subset(trainset, client_indices)
    # create dataloader 
    local_dataloder = torch.utils.data.DataLoader(subset, batch_size=batch_size)

    local_dataloaders.append(local_dataloder)
# Out:
# tensor([3152, 2680, 3892,  ..., 3555, 4714, 1882])

# %%
len(local_dataloaders[0])
# Out:
# 32

# %%
trainset = ZenseactDataset(5000)
trainset.folders
# Out:
# ['../../../mnt/nfs_mount/single_frames/000000',
#  '../../../mnt/nfs_mount/single_frames/000001',
#  '../../../mnt/nfs_mount/single_frames/000002',
#  '../../../mnt/nfs_mount/single_frames/000003',
#  '../../../mnt/nfs_mount/single_frames/000004',
#  '../../../mnt/nfs_mount/single_frames/000005',
#  '../../../mnt/nfs_mount/single_frames/000006',
#  '../../../mnt/nfs_mount/single_frames/000007',
#  '../../../mnt/nfs_mount/single_frames/000008',
#  '../../../mnt/nfs_mount/single_frames/000009',
#  '../../../mnt/nfs_mount/single_frames/000010',
#  '../../../mnt/nfs_mount/single_frames/000011',
#  '../../../mnt/nfs_mount/single_frames/000012',
#  '../../../mnt/nfs_mount/single_frames/000013',
#  '../../../mnt/nfs_mount/single_frames/000014',
#  '../../../mnt/nfs_mount/single_frames/000015',
#  '../../../mnt/nfs_mount/single_frames/000016',
#  '../../../mnt/nfs_mount/single_frames/000017',
#  '../../../mnt/nfs_mount/single_frames/000018',
#  '../../../mnt/nfs_mount/single_frames/000019',
#  '../../../mnt/nfs_mount/single_frames/000020',
#  '../../../mnt/nfs_mount/single_frames/000021',
#  '../../../mnt/nfs_mount/single_frames/000022',
#  '../../../mnt/nfs_mount/single_frames/000023',
#  '../../../mnt/nfs_mount/single_frames/000024',
#  '../../../mnt/nfs_mount/single_frames/000025',
#  '../../../mnt/nfs_mount/single_frames/000026',
#  '../../../mnt/nfs_mount/single_frames/000027',
#  '../../../mnt/nfs_mount/single_frames/000028',
#  '../../../mnt/nfs_mount/single_frames/000029',
#  '../../../mnt/nfs_mount/single_frames/000030',
#  '../../../mnt/nfs_mount/single_frames/000031',
#  '../../../mnt/nfs_mount/single_frames/000032',
#  '../../../mnt/nfs_mount/single_frames/000033',
#  '../../../mnt/nfs_mount/single_frames/000034',
#  '../../../mnt/nfs_mount/single_frames/000035',
#  '../../../mnt/nfs_mount/single_frames/000036',
#  '../../../mnt/nfs_mount/single_frames/000037',
#  '../../../mnt/nfs_mount/single_frames/000038',
#  '../../../mnt/nfs_mount/single_frames/000039',
#  '../../../mnt/nfs_mount/single_frames/000040',
#  '../../../mnt/nfs_mount/single_frames/000041',
#  '../../../mnt/nfs_mount/single_frames/000042',
#  '../../../mnt/nfs_mount/single_frames/000043',
#  '../../../mnt/nfs_mount/single_frames/000044',
#  '../../../mnt/nfs_mount/single_frames/000045',
#  '../../../mnt/nfs_mount/single_frames/000046',
#  '../../../mnt/nfs_mount/single_frames/000047',
#  '../../../mnt/nfs_mount/single_frames/000048',
#  '../../../mnt/nfs_mount/single_frames/000049',
#  '../../../mnt/nfs_mount/single_frames/000050',
#  '../../../mnt/nfs_mount/single_frames/000051',
#  '../../../mnt/nfs_mount/single_frames/000052',
#  '../../../mnt/nfs_mount/single_frames/000053',
#  '../../../mnt/nfs_mount/single_frames/000054',
#  '../../../mnt/nfs_mount/single_frames/000055',
#  '../../../mnt/nfs_mount/single_frames/000056',
#  '../../../mnt/nfs_mount/single_frames/000057',
#  '../../../mnt/nfs_mount/single_frames/000058',
#  '../../../mnt/nfs_mount/single_frames/000059',
#  '../../../mnt/nfs_mount/single_frames/000060',
#  '../../../mnt/nfs_mount/single_frames/000061',
#  '../../../mnt/nfs_mount/single_frames/000062',
#  '../../../mnt/nfs_mount/single_frames/000063',
#  '../../../mnt/nfs_mount/single_frames/000064',
#  '../../../mnt/nfs_mount/single_frames/000065',
#  '../../../mnt/nfs_mount/single_frames/000066',
#  '../../../mnt/nfs_mount/single_frames/000067',
#  '../../../mnt/nfs_mount/single_frames/000068',
#  '../../../mnt/nfs_mount/single_frames/000069',
#  '../../../mnt/nfs_mount/single_frames/000070',
#  '../../../mnt/nfs_mount/single_frames/000071',
#  '../../../mnt/nfs_mount/single_frames/000072',
#  '../../../mnt/nfs_mount/single_frames/000073',
#  '../../../mnt/nfs_mount/single_frames/000074',
#  '../../../mnt/nfs_mount/single_frames/000075',
#  '../../../mnt/nfs_mount/single_frames/000076',
#  '../../../mnt/nfs_mount/single_frames/000077',
#  '../../../mnt/nfs_mount/single_frames/000078',
#  '../../../mnt/nfs_mount/single_frames/000079',
#  '../../../mnt/nfs_mount/single_frames/000080',
#  '../../../mnt/nfs_mount/single_frames/000081',
#  '../../../mnt/nfs_mount/single_frames/000082',
#  '../../../mnt/nfs_mount/single_frames/000083',
#  '../../../mnt/nfs_mount/single_frames/000084',
#  '../../../mnt/nfs_mount/single_frames/000085',
#  '../../../mnt/nfs_mount/single_frames/000086',
#  '../../../mnt/nfs_mount/single_frames/000087',
#  '../../../mnt/nfs_mount/single_frames/000088',
#  '../../../mnt/nfs_mount/single_frames/000089',
#  '../../../mnt/nfs_mount/single_frames/000090',
#  '../../../mnt/nfs_mount/single_frames/000091',
#  '../../../mnt/nfs_mount/single_frames/000092',
#  '../../../mnt/nfs_mount/single_frames/000093',
#  '../../../mnt/nfs_mount/single_frames/000094',
#  '../../../mnt/nfs_mount/single_frames/000095',
#  '../../../mnt/nfs_mount/single_frames/000096',
#  '../../../mnt/nfs_mount/single_frames/000097',
#  '../../../mnt/nfs_mount/single_frames/000098',
#  '../../../mnt/nfs_mount/single_frames/000099',
#  '../../../mnt/nfs_mount/single_frames/000100',
#  '../../../mnt/nfs_mount/single_frames/000101',
#  '../../../mnt/nfs_mount/single_frames/000102',
#  '../../../mnt/nfs_mount/single_frames/000103',
#  '../../../mnt/nfs_mount/single_frames/000104',
#  '../../../mnt/nfs_mount/single_frames/000105',
#  '../../../mnt/nfs_mount/single_frames/000106',
#  '../../../mnt/nfs_mount/single_frames/000107',
#  '../../../mnt/nfs_mount/single_frames/000108',
#  '../../../mnt/nfs_mount/single_frames/000109',
#  '../../../mnt/nfs_mount/single_frames/000110',
#  '../../../mnt/nfs_mount/single_frames/000111',
#  '../../../mnt/nfs_mount/single_frames/000112',
#  '../../../mnt/nfs_mount/single_frames/000113',
#  '../../../mnt/nfs_mount/single_frames/000114',
#  '../../../mnt/nfs_mount/single_frames/000115',
#  '../../../mnt/nfs_mount/single_frames/000116',
#  '../../../mnt/nfs_mount/single_frames/000117',
#  '../../../mnt/nfs_mount/single_frames/000118',
#  '../../../mnt/nfs_mount/single_frames/000119',
#  '../../../mnt/nfs_mount/single_frames/000120',
#  '../../../mnt/nfs_mount/single_frames/000121',
#  '../../../mnt/nfs_mount/single_frames/000122',
#  '../../../mnt/nfs_mount/single_frames/000123',
#  '../../../mnt/nfs_mount/single_frames/000124',
#  '../../../mnt/nfs_mount/single_frames/000125',
#  '../../../mnt/nfs_mount/single_frames/000126',
#  '../../../mnt/nfs_mount/single_frames/000127',
#  '../../../mnt/nfs_mount/single_frames/000128',
#  '../../../mnt/nfs_mount/single_frames/000129',
#  '../../../mnt/nfs_mount/single_frames/000130',
#  '../../../mnt/nfs_mount/single_frames/000131',
#  '../../../mnt/nfs_mount/single_frames/000132',
#  '../../../mnt/nfs_mount/single_frames/000133',
#  '../../../mnt/nfs_mount/single_frames/000134',
#  '../../../mnt/nfs_mount/single_frames/000135',
#  '../../../mnt/nfs_mount/single_frames/000136',
#  '../../../mnt/nfs_mount/single_frames/000137',
#  '../../../mnt/nfs_mount/single_frames/000138',
#  '../../../mnt/nfs_mount/single_frames/000139',
#  '../../../mnt/nfs_mount/single_frames/000140',
#  '../../../mnt/nfs_mount/single_frames/000141',
#  '../../../mnt/nfs_mount/single_frames/000142',
#  '../../../mnt/nfs_mount/single_frames/000143',
#  '../../../mnt/nfs_mount/single_frames/000144',
#  '../../../mnt/nfs_mount/single_frames/000145',
#  '../../../mnt/nfs_mount/single_frames/000146',
#  '../../../mnt/nfs_mount/single_frames/000147',
#  '../../../mnt/nfs_mount/single_frames/000148',
#  '../../../mnt/nfs_mount/single_frames/000149',
#  '../../../mnt/nfs_mount/single_frames/000150',
#  '../../../mnt/nfs_mount/single_frames/000151',
#  '../../../mnt/nfs_mount/single_frames/000152',
#  '../../../mnt/nfs_mount/single_frames/000153',
#  '../../../mnt/nfs_mount/single_frames/000154',
#  '../../../mnt/nfs_mount/single_frames/000155',
#  '../../../mnt/nfs_mount/single_frames/000156',
#  '../../../mnt/nfs_mount/single_frames/000157',
#  '../../../mnt/nfs_mount/single_frames/000158',
#  '../../../mnt/nfs_mount/single_frames/000159',
#  '../../../mnt/nfs_mount/single_frames/000160',
#  '../../../mnt/nfs_mount/single_frames/000161',
#  '../../../mnt/nfs_mount/single_frames/000162',
#  '../../../mnt/nfs_mount/single_frames/000163',
#  '../../../mnt/nfs_mount/single_frames/000164',
#  '../../../mnt/nfs_mount/single_frames/000165',
#  '../../../mnt/nfs_mount/single_frames/000166',
#  '../../../mnt/nfs_mount/single_frames/000167',
#  '../../../mnt/nfs_mount/single_frames/000168',
#  '../../../mnt/nfs_mount/single_frames/000169',
#  '../../../mnt/nfs_mount/single_frames/000170',
#  '../../../mnt/nfs_mount/single_frames/000171',
#  '../../../mnt/nfs_mount/single_frames/000172',
#  '../../../mnt/nfs_mount/single_frames/000173',
#  '../../../mnt/nfs_mount/single_frames/000174',
#  '../../../mnt/nfs_mount/single_frames/000175',
#  '../../../mnt/nfs_mount/single_frames/000176',
#  '../../../mnt/nfs_mount/single_frames/000177',
#  '../../../mnt/nfs_mount/single_frames/000178',
#  '../../../mnt/nfs_mount/single_frames/000179',
#  '../../../mnt/nfs_mount/single_frames/000180',
#  '../../../mnt/nfs_mount/single_frames/000181',
#  '../../../mnt/nfs_mount/single_frames/000182',
#  '../../../mnt/nfs_mount/single_frames/000183',
#  '../../../mnt/nfs_mount/single_frames/000184',
#  '../../../mnt/nfs_mount/single_frames/000185',
#  '../../../mnt/nfs_mount/single_frames/000186',
#  '../../../mnt/nfs_mount/single_frames/000187',
#  '../../../mnt/nfs_mount/single_frames/000188',
#  '../../../mnt/nfs_mount/single_frames/000189',
#  '../../../mnt/nfs_mount/single_frames/000190',
#  '../../../mnt/nfs_mount/single_frames/000191',
#  '../../../mnt/nfs_mount/single_frames/000192',
#  '../../../mnt/nfs_mount/single_frames/000193',
#  '../../../mnt/nfs_mount/single_frames/000194',
#  '../../../mnt/nfs_mount/single_frames/000195',
#  '../../../mnt/nfs_mount/single_frames/000196',
#  '../../../mnt/nfs_mount/single_frames/000197',
#  '../../../mnt/nfs_mount/single_frames/000198',
#  '../../../mnt/nfs_mount/single_frames/000199',
#  '../../../mnt/nfs_mount/single_frames/000200',
#  '../../../mnt/nfs_mount/single_frames/000201',
#  '../../../mnt/nfs_mount/single_frames/000202',
#  '../../../mnt/nfs_mount/single_frames/000203',
#  '../../../mnt/nfs_mount/single_frames/000204',
#  '../../../mnt/nfs_mount/single_frames/000205',
#  '../../../mnt/nfs_mount/single_frames/000206',
#  '../../../mnt/nfs_mount/single_frames/000207',
#  '../../../mnt/nfs_mount/single_frames/000208',
#  '../../../mnt/nfs_mount/single_frames/000209',
#  '../../../mnt/nfs_mount/single_frames/000210',
#  '../../../mnt/nfs_mount/single_frames/000211',
#  '../../../mnt/nfs_mount/single_frames/000212',
#  '../../../mnt/nfs_mount/single_frames/000213',
#  '../../../mnt/nfs_mount/single_frames/000214',
#  '../../../mnt/nfs_mount/single_frames/000215',
#  '../../../mnt/nfs_mount/single_frames/000216',
#  '../../../mnt/nfs_mount/single_frames/000217',
#  '../../../mnt/nfs_mount/single_frames/000218',
#  '../../../mnt/nfs_mount/single_frames/000219',
#  '../../../mnt/nfs_mount/single_frames/000220',
#  '../../../mnt/nfs_mount/single_frames/000221',
#  '../../../mnt/nfs_mount/single_frames/000222',
#  '../../../mnt/nfs_mount/single_frames/000223',
#  '../../../mnt/nfs_mount/single_frames/000224',
#  '../../../mnt/nfs_mount/single_frames/000225',
#  '../../../mnt/nfs_mount/single_frames/000226',
#  '../../../mnt/nfs_mount/single_frames/000227',
#  '../../../mnt/nfs_mount/single_frames/000228',
#  '../../../mnt/nfs_mount/single_frames/000229',
#  '../../../mnt/nfs_mount/single_frames/000230',
#  '../../../mnt/nfs_mount/single_frames/000231',
#  '../../../mnt/nfs_mount/single_frames/000232',
#  '../../../mnt/nfs_mount/single_frames/000233',
#  '../../../mnt/nfs_mount/single_frames/000234',
#  '../../../mnt/nfs_mount/single_frames/000235',
#  '../../../mnt/nfs_mount/single_frames/000236',
#  '../../../mnt/nfs_mount/single_frames/000237',
#  '../../../mnt/nfs_mount/single_frames/000238',
#  '../../../mnt/nfs_mount/single_frames/000239',
#  '../../../mnt/nfs_mount/single_frames/000240',
#  '../../../mnt/nfs_mount/single_frames/000241',
#  '../../../mnt/nfs_mount/single_frames/000242',
#  '../../../mnt/nfs_mount/single_frames/000243',
#  '../../../mnt/nfs_mount/single_frames/000244',
#  '../../../mnt/nfs_mount/single_frames/000245',
#  '../../../mnt/nfs_mount/single_frames/000246',
#  '../../../mnt/nfs_mount/single_frames/000247',
#  '../../../mnt/nfs_mount/single_frames/000248',
#  '../../../mnt/nfs_mount/single_frames/000249',
#  '../../../mnt/nfs_mount/single_frames/000250',
#  '../../../mnt/nfs_mount/single_frames/000251',
#  '../../../mnt/nfs_mount/single_frames/000252',
#  '../../../mnt/nfs_mount/single_frames/000253',
#  '../../../mnt/nfs_mount/single_frames/000254',
#  '../../../mnt/nfs_mount/single_frames/000255',
#  '../../../mnt/nfs_mount/single_frames/000256',
#  '../../../mnt/nfs_mount/single_frames/000257',
#  '../../../mnt/nfs_mount/single_frames/000258',
#  '../../../mnt/nfs_mount/single_frames/000259',
#  '../../../mnt/nfs_mount/single_frames/000260',
#  '../../../mnt/nfs_mount/single_frames/000261',
#  '../../../mnt/nfs_mount/single_frames/000262',
#  '../../../mnt/nfs_mount/single_frames/000263',
#  '../../../mnt/nfs_mount/single_frames/000264',
#  '../../../mnt/nfs_mount/single_frames/000265',
#  '../../../mnt/nfs_mount/single_frames/000266',
#  '../../../mnt/nfs_mount/single_frames/000267',
#  '../../../mnt/nfs_mount/single_frames/000268',
#  '../../../mnt/nfs_mount/single_frames/000269',
#  '../../../mnt/nfs_mount/single_frames/000270',
#  '../../../mnt/nfs_mount/single_frames/000271',
#  '../../../mnt/nfs_mount/single_frames/000272',
#  '../../../mnt/nfs_mount/single_frames/000273',
#  '../../../mnt/nfs_mount/single_frames/000274',
#  '../../../mnt/nfs_mount/single_frames/000275',
#  '../../../mnt/nfs_mount/single_frames/000276',
#  '../../../mnt/nfs_mount/single_frames/000277',
#  '../../../mnt/nfs_mount/single_frames/000278',
#  '../../../mnt/nfs_mount/single_frames/000279',
#  '../../../mnt/nfs_mount/single_frames/000280',
#  '../../../mnt/nfs_mount/single_frames/000281',
#  '../../../mnt/nfs_mount/single_frames/000282',
#  '../../../mnt/nfs_mount/single_frames/000283',
#  '../../../mnt/nfs_mount/single_frames/000284',
#  '../../../mnt/nfs_mount/single_frames/000285',
#  '../../../mnt/nfs_mount/single_frames/000286',
#  '../../../mnt/nfs_mount/single_frames/000287',
#  '../../../mnt/nfs_mount/single_frames/000288',
#  '../../../mnt/nfs_mount/single_frames/000289',
#  '../../../mnt/nfs_mount/single_frames/000290',
#  '../../../mnt/nfs_mount/single_frames/000291',
#  '../../../mnt/nfs_mount/single_frames/000292',
#  '../../../mnt/nfs_mount/single_frames/000293',
#  '../../../mnt/nfs_mount/single_frames/000294',
#  '../../../mnt/nfs_mount/single_frames/000295',
#  '../../../mnt/nfs_mount/single_frames/000296',
#  '../../../mnt/nfs_mount/single_frames/000297',
#  '../../../mnt/nfs_mount/single_frames/000298',
#  '../../../mnt/nfs_mount/single_frames/000299',
#  '../../../mnt/nfs_mount/single_frames/000300',
#  '../../../mnt/nfs_mount/single_frames/000301',
#  '../../../mnt/nfs_mount/single_frames/000302',
#  '../../../mnt/nfs_mount/single_frames/000303',
#  '../../../mnt/nfs_mount/single_frames/000304',
#  '../../../mnt/nfs_mount/single_frames/000305',
#  '../../../mnt/nfs_mount/single_frames/000306',
#  '../../../mnt/nfs_mount/single_frames/000307',
#  '../../../mnt/nfs_mount/single_frames/000308',
#  '../../../mnt/nfs_mount/single_frames/000309',
#  '../../../mnt/nfs_mount/single_frames/000310',
#  '../../../mnt/nfs_mount/single_frames/000311',
#  '../../../mnt/nfs_mount/single_frames/000312',
#  '../../../mnt/nfs_mount/single_frames/000313',
#  '../../../mnt/nfs_mount/single_frames/000314',
#  '../../../mnt/nfs_mount/single_frames/000315',
#  '../../../mnt/nfs_mount/single_frames/000316',
#  '../../../mnt/nfs_mount/single_frames/000317',
#  '../../../mnt/nfs_mount/single_frames/000318',
#  '../../../mnt/nfs_mount/single_frames/000319',
#  '../../../mnt/nfs_mount/single_frames/000320',
#  '../../../mnt/nfs_mount/single_frames/000321',
#  '../../../mnt/nfs_mount/single_frames/000322',
#  '../../../mnt/nfs_mount/single_frames/000323',
#  '../../../mnt/nfs_mount/single_frames/000324',
#  '../../../mnt/nfs_mount/single_frames/000325',
#  '../../../mnt/nfs_mount/single_frames/000326',
#  '../../../mnt/nfs_mount/single_frames/000327',
#  '../../../mnt/nfs_mount/single_frames/000328',
#  '../../../mnt/nfs_mount/single_frames/000329',
#  '../../../mnt/nfs_mount/single_frames/000330',
#  '../../../mnt/nfs_mount/single_frames/000331',
#  '../../../mnt/nfs_mount/single_frames/000332',
#  '../../../mnt/nfs_mount/single_frames/000333',
#  '../../../mnt/nfs_mount/single_frames/000334',
#  '../../../mnt/nfs_mount/single_frames/000335',
#  '../../../mnt/nfs_mount/single_frames/000336',
#  '../../../mnt/nfs_mount/single_frames/000337',
#  '../../../mnt/nfs_mount/single_frames/000338',
#  '../../../mnt/nfs_mount/single_frames/000339',
#  '../../../mnt/nfs_mount/single_frames/000340',
#  '../../../mnt/nfs_mount/single_frames/000341',
#  '../../../mnt/nfs_mount/single_frames/000342',
#  '../../../mnt/nfs_mount/single_frames/000343',
#  '../../../mnt/nfs_mount/single_frames/000344',
#  '../../../mnt/nfs_mount/single_frames/000345',
#  '../../../mnt/nfs_mount/single_frames/000346',
#  '../../../mnt/nfs_mount/single_frames/000347',
#  '../../../mnt/nfs_mount/single_frames/000348',
#  '../../../mnt/nfs_mount/single_frames/000349',
#  '../../../mnt/nfs_mount/single_frames/000350',
#  '../../../mnt/nfs_mount/single_frames/000351',
#  '../../../mnt/nfs_mount/single_frames/000352',
#  '../../../mnt/nfs_mount/single_frames/000353',
#  '../../../mnt/nfs_mount/single_frames/000354',
#  '../../../mnt/nfs_mount/single_frames/000355',
#  '../../../mnt/nfs_mount/single_frames/000356',
#  '../../../mnt/nfs_mount/single_frames/000357',
#  '../../../mnt/nfs_mount/single_frames/000358',
#  '../../../mnt/nfs_mount/single_frames/000359',
#  '../../../mnt/nfs_mount/single_frames/000360',
#  '../../../mnt/nfs_mount/single_frames/000361',
#  '../../../mnt/nfs_mount/single_frames/000362',
#  '../../../mnt/nfs_mount/single_frames/000363',
#  '../../../mnt/nfs_mount/single_frames/000364',
#  '../../../mnt/nfs_mount/single_frames/000365',
#  '../../../mnt/nfs_mount/single_frames/000366',
#  '../../../mnt/nfs_mount/single_frames/000367',
#  '../../../mnt/nfs_mount/single_frames/000368',
#  '../../../mnt/nfs_mount/single_frames/000369',
#  '../../../mnt/nfs_mount/single_frames/000370',
#  '../../../mnt/nfs_mount/single_frames/000371',
#  '../../../mnt/nfs_mount/single_frames/000372',
#  '../../../mnt/nfs_mount/single_frames/000373',
#  '../../../mnt/nfs_mount/single_frames/000374',
#  '../../../mnt/nfs_mount/single_frames/000375',
#  '../../../mnt/nfs_mount/single_frames/000376',
#  '../../../mnt/nfs_mount/single_frames/000377',
#  '../../../mnt/nfs_mount/single_frames/000378',
#  '../../../mnt/nfs_mount/single_frames/000379',
#  '../../../mnt/nfs_mount/single_frames/000380',
#  '../../../mnt/nfs_mount/single_frames/000381',
#  '../../../mnt/nfs_mount/single_frames/000382',
#  '../../../mnt/nfs_mount/single_frames/000383',
#  '../../../mnt/nfs_mount/single_frames/000384',
#  '../../../mnt/nfs_mount/single_frames/000385',
#  '../../../mnt/nfs_mount/single_frames/000386',
#  '../../../mnt/nfs_mount/single_frames/000387',
#  '../../../mnt/nfs_mount/single_frames/000388',
#  '../../../mnt/nfs_mount/single_frames/000389',
#  '../../../mnt/nfs_mount/single_frames/000390',
#  '../../../mnt/nfs_mount/single_frames/000391',
#  '../../../mnt/nfs_mount/single_frames/000392',
#  '../../../mnt/nfs_mount/single_frames/000393',
#  '../../../mnt/nfs_mount/single_frames/000394',
#  '../../../mnt/nfs_mount/single_frames/000395',
#  '../../../mnt/nfs_mount/single_frames/000396',
#  '../../../mnt/nfs_mount/single_frames/000397',
#  '../../../mnt/nfs_mount/single_frames/000398',
#  '../../../mnt/nfs_mount/single_frames/000399',
#  '../../../mnt/nfs_mount/single_frames/000400',
#  '../../../mnt/nfs_mount/single_frames/000401',
#  '../../../mnt/nfs_mount/single_frames/000402',
#  '../../../mnt/nfs_mount/single_frames/000403',
#  '../../../mnt/nfs_mount/single_frames/000404',
#  '../../../mnt/nfs_mount/single_frames/000405',
#  '../../../mnt/nfs_mount/single_frames/000406',
#  '../../../mnt/nfs_mount/single_frames/000407',
#  '../../../mnt/nfs_mount/single_frames/000408',
#  '../../../mnt/nfs_mount/single_frames/000409',
#  '../../../mnt/nfs_mount/single_frames/000410',
#  '../../../mnt/nfs_mount/single_frames/000411',
#  '../../../mnt/nfs_mount/single_frames/000412',
#  '../../../mnt/nfs_mount/single_frames/000413',
#  '../../../mnt/nfs_mount/single_frames/000414',
#  '../../../mnt/nfs_mount/single_frames/000415',
#  '../../../mnt/nfs_mount/single_frames/000416',
#  '../../../mnt/nfs_mount/single_frames/000417',
#  '../../../mnt/nfs_mount/single_frames/000418',
#  '../../../mnt/nfs_mount/single_frames/000419',
#  '../../../mnt/nfs_mount/single_frames/000420',
#  '../../../mnt/nfs_mount/single_frames/000421',
#  '../../../mnt/nfs_mount/single_frames/000422',
#  '../../../mnt/nfs_mount/single_frames/000423',
#  '../../../mnt/nfs_mount/single_frames/000424',
#  '../../../mnt/nfs_mount/single_frames/000425',
#  '../../../mnt/nfs_mount/single_frames/000426',
#  '../../../mnt/nfs_mount/single_frames/000427',
#  '../../../mnt/nfs_mount/single_frames/000428',
#  '../../../mnt/nfs_mount/single_frames/000429',
#  '../../../mnt/nfs_mount/single_frames/000430',
#  '../../../mnt/nfs_mount/single_frames/000431',
#  '../../../mnt/nfs_mount/single_frames/000432',
#  '../../../mnt/nfs_mount/single_frames/000433',
#  '../../../mnt/nfs_mount/single_frames/000434',
#  '../../../mnt/nfs_mount/single_frames/000435',
#  '../../../mnt/nfs_mount/single_frames/000436',
#  '../../../mnt/nfs_mount/single_frames/000437',
#  '../../../mnt/nfs_mount/single_frames/000438',
#  '../../../mnt/nfs_mount/single_frames/000439',
#  '../../../mnt/nfs_mount/single_frames/000440',
#  '../../../mnt/nfs_mount/single_frames/000441',
#  '../../../mnt/nfs_mount/single_frames/000442',
#  '../../../mnt/nfs_mount/single_frames/000443',
#  '../../../mnt/nfs_mount/single_frames/000444',
#  '../../../mnt/nfs_mount/single_frames/000445',
#  '../../../mnt/nfs_mount/single_frames/000446',
#  '../../../mnt/nfs_mount/single_frames/000447',
#  '../../../mnt/nfs_mount/single_frames/000448',
#  '../../../mnt/nfs_mount/single_frames/000449',
#  '../../../mnt/nfs_mount/single_frames/000450',
#  '../../../mnt/nfs_mount/single_frames/000451',
#  '../../../mnt/nfs_mount/single_frames/000452',
#  '../../../mnt/nfs_mount/single_frames/000453',
#  '../../../mnt/nfs_mount/single_frames/000454',
#  '../../../mnt/nfs_mount/single_frames/000455',
#  '../../../mnt/nfs_mount/single_frames/000456',
#  '../../../mnt/nfs_mount/single_frames/000457',
#  '../../../mnt/nfs_mount/single_frames/000458',
#  '../../../mnt/nfs_mount/single_frames/000459',
#  '../../../mnt/nfs_mount/single_frames/000460',
#  '../../../mnt/nfs_mount/single_frames/000461',
#  '../../../mnt/nfs_mount/single_frames/000462',
#  '../../../mnt/nfs_mount/single_frames/000463',
#  '../../../mnt/nfs_mount/single_frames/000464',
#  '../../../mnt/nfs_mount/single_frames/000465',
#  '../../../mnt/nfs_mount/single_frames/000466',
#  '../../../mnt/nfs_mount/single_frames/000467',
#  '../../../mnt/nfs_mount/single_frames/000468',
#  '../../../mnt/nfs_mount/single_frames/000469',
#  '../../../mnt/nfs_mount/single_frames/000470',
#  '../../../mnt/nfs_mount/single_frames/000471',
#  '../../../mnt/nfs_mount/single_frames/000472',
#  '../../../mnt/nfs_mount/single_frames/000473',
#  '../../../mnt/nfs_mount/single_frames/000474',
#  '../../../mnt/nfs_mount/single_frames/000475',
#  '../../../mnt/nfs_mount/single_frames/000476',
#  '../../../mnt/nfs_mount/single_frames/000477',
#  '../../../mnt/nfs_mount/single_frames/000478',
#  '../../../mnt/nfs_mount/single_frames/000479',
#  '../../../mnt/nfs_mount/single_frames/000480',
#  '../../../mnt/nfs_mount/single_frames/000481',
#  '../../../mnt/nfs_mount/single_frames/000482',
#  '../../../mnt/nfs_mount/single_frames/000483',
#  '../../../mnt/nfs_mount/single_frames/000484',
#  '../../../mnt/nfs_mount/single_frames/000485',
#  '../../../mnt/nfs_mount/single_frames/000486',
#  '../../../mnt/nfs_mount/single_frames/000487',
#  '../../../mnt/nfs_mount/single_frames/000488',
#  '../../../mnt/nfs_mount/single_frames/000489',
#  '../../../mnt/nfs_mount/single_frames/000490',
#  '../../../mnt/nfs_mount/single_frames/000491',
#  '../../../mnt/nfs_mount/single_frames/000492',
#  '../../../mnt/nfs_mount/single_frames/000493',
#  '../../../mnt/nfs_mount/single_frames/000494',
#  '../../../mnt/nfs_mount/single_frames/000495',
#  '../../../mnt/nfs_mount/single_frames/000496',
#  '../../../mnt/nfs_mount/single_frames/000497',
#  '../../../mnt/nfs_mount/single_frames/000498',
#  '../../../mnt/nfs_mount/single_frames/000499',
#  '../../../mnt/nfs_mount/single_frames/000500',
#  '../../../mnt/nfs_mount/single_frames/000501',
#  '../../../mnt/nfs_mount/single_frames/000502',
#  '../../../mnt/nfs_mount/single_frames/000503',
#  '../../../mnt/nfs_mount/single_frames/000504',
#  '../../../mnt/nfs_mount/single_frames/000505',
#  '../../../mnt/nfs_mount/single_frames/000506',
#  '../../../mnt/nfs_mount/single_frames/000507',
#  '../../../mnt/nfs_mount/single_frames/000508',
#  '../../../mnt/nfs_mount/single_frames/000509',
#  '../../../mnt/nfs_mount/single_frames/000510',
#  '../../../mnt/nfs_mount/single_frames/000511',
#  '../../../mnt/nfs_mount/single_frames/000512',
#  '../../../mnt/nfs_mount/single_frames/000513',
#  '../../../mnt/nfs_mount/single_frames/000514',
#  '../../../mnt/nfs_mount/single_frames/000515',
#  '../../../mnt/nfs_mount/single_frames/000516',
#  '../../../mnt/nfs_mount/single_frames/000517',
#  '../../../mnt/nfs_mount/single_frames/000518',
#  '../../../mnt/nfs_mount/single_frames/000519',
#  '../../../mnt/nfs_mount/single_frames/000520',
#  '../../../mnt/nfs_mount/single_frames/000521',
#  '../../../mnt/nfs_mount/single_frames/000522',
#  '../../../mnt/nfs_mount/single_frames/000523',
#  '../../../mnt/nfs_mount/single_frames/000524',
#  '../../../mnt/nfs_mount/single_frames/000525',
#  '../../../mnt/nfs_mount/single_frames/000526',
#  '../../../mnt/nfs_mount/single_frames/000527',
#  '../../../mnt/nfs_mount/single_frames/000528',
#  '../../../mnt/nfs_mount/single_frames/000529',
#  '../../../mnt/nfs_mount/single_frames/000530',
#  '../../../mnt/nfs_mount/single_frames/000531',
#  '../../../mnt/nfs_mount/single_frames/000532',
#  '../../../mnt/nfs_mount/single_frames/000533',
#  '../../../mnt/nfs_mount/single_frames/000534',
#  '../../../mnt/nfs_mount/single_frames/000535',
#  '../../../mnt/nfs_mount/single_frames/000536',
#  '../../../mnt/nfs_mount/single_frames/000537',
#  '../../../mnt/nfs_mount/single_frames/000538',
#  '../../../mnt/nfs_mount/single_frames/000539',
#  '../../../mnt/nfs_mount/single_frames/000540',
#  '../../../mnt/nfs_mount/single_frames/000541',
#  '../../../mnt/nfs_mount/single_frames/000542',
#  '../../../mnt/nfs_mount/single_frames/000543',
#  '../../../mnt/nfs_mount/single_frames/000544',
#  '../../../mnt/nfs_mount/single_frames/000545',
#  '../../../mnt/nfs_mount/single_frames/000546',
#  '../../../mnt/nfs_mount/single_frames/000547',
#  '../../../mnt/nfs_mount/single_frames/000548',
#  '../../../mnt/nfs_mount/single_frames/000549',
#  '../../../mnt/nfs_mount/single_frames/000550',
#  '../../../mnt/nfs_mount/single_frames/000551',
#  '../../../mnt/nfs_mount/single_frames/000552',
#  '../../../mnt/nfs_mount/single_frames/000553',
#  '../../../mnt/nfs_mount/single_frames/000554',
#  '../../../mnt/nfs_mount/single_frames/000555',
#  '../../../mnt/nfs_mount/single_frames/000556',
#  '../../../mnt/nfs_mount/single_frames/000557',
#  '../../../mnt/nfs_mount/single_frames/000558',
#  '../../../mnt/nfs_mount/single_frames/000559',
#  '../../../mnt/nfs_mount/single_frames/000560',
#  '../../../mnt/nfs_mount/single_frames/000561',
#  '../../../mnt/nfs_mount/single_frames/000562',
#  '../../../mnt/nfs_mount/single_frames/000563',
#  '../../../mnt/nfs_mount/single_frames/000564',
#  '../../../mnt/nfs_mount/single_frames/000565',
#  '../../../mnt/nfs_mount/single_frames/000566',
#  '../../../mnt/nfs_mount/single_frames/000567',
#  '../../../mnt/nfs_mount/single_frames/000568',
#  '../../../mnt/nfs_mount/single_frames/000569',
#  '../../../mnt/nfs_mount/single_frames/000570',
#  '../../../mnt/nfs_mount/single_frames/000571',
#  '../../../mnt/nfs_mount/single_frames/000572',
#  '../../../mnt/nfs_mount/single_frames/000573',
#  '../../../mnt/nfs_mount/single_frames/000574',
#  '../../../mnt/nfs_mount/single_frames/000575',
#  '../../../mnt/nfs_mount/single_frames/000576',
#  '../../../mnt/nfs_mount/single_frames/000577',
#  '../../../mnt/nfs_mount/single_frames/000578',
#  '../../../mnt/nfs_mount/single_frames/000579',
#  '../../../mnt/nfs_mount/single_frames/000580',
#  '../../../mnt/nfs_mount/single_frames/000581',
#  '../../../mnt/nfs_mount/single_frames/000582',
#  '../../../mnt/nfs_mount/single_frames/000583',
#  '../../../mnt/nfs_mount/single_frames/000584',
#  '../../../mnt/nfs_mount/single_frames/000585',
#  '../../../mnt/nfs_mount/single_frames/000586',
#  '../../../mnt/nfs_mount/single_frames/000587',
#  '../../../mnt/nfs_mount/single_frames/000588',
#  '../../../mnt/nfs_mount/single_frames/000589',
#  '../../../mnt/nfs_mount/single_frames/000590',
#  '../../../mnt/nfs_mount/single_frames/000591',
#  '../../../mnt/nfs_mount/single_frames/000592',
#  '../../../mnt/nfs_mount/single_frames/000593',
#  '../../../mnt/nfs_mount/single_frames/000594',
#  '../../../mnt/nfs_mount/single_frames/000595',
#  '../../../mnt/nfs_mount/single_frames/000596',
#  '../../../mnt/nfs_mount/single_frames/000597',
#  '../../../mnt/nfs_mount/single_frames/000598',
#  '../../../mnt/nfs_mount/single_frames/000599',
#  '../../../mnt/nfs_mount/single_frames/000600',
#  '../../../mnt/nfs_mount/single_frames/000601',
#  '../../../mnt/nfs_mount/single_frames/000602',
#  '../../../mnt/nfs_mount/single_frames/000603',
#  '../../../mnt/nfs_mount/single_frames/000604',
#  '../../../mnt/nfs_mount/single_frames/000605',
#  '../../../mnt/nfs_mount/single_frames/000606',
#  '../../../mnt/nfs_mount/single_frames/000607',
#  '../../../mnt/nfs_mount/single_frames/000608',
#  '../../../mnt/nfs_mount/single_frames/000609',
#  '../../../mnt/nfs_mount/single_frames/000610',
#  '../../../mnt/nfs_mount/single_frames/000611',
#  '../../../mnt/nfs_mount/single_frames/000612',
#  '../../../mnt/nfs_mount/single_frames/000613',
#  '../../../mnt/nfs_mount/single_frames/000614',
#  '../../../mnt/nfs_mount/single_frames/000615',
#  '../../../mnt/nfs_mount/single_frames/000616',
#  '../../../mnt/nfs_mount/single_frames/000617',
#  '../../../mnt/nfs_mount/single_frames/000618',
#  '../../../mnt/nfs_mount/single_frames/000619',
#  '../../../mnt/nfs_mount/single_frames/000620',
#  '../../../mnt/nfs_mount/single_frames/000621',
#  '../../../mnt/nfs_mount/single_frames/000622',
#  '../../../mnt/nfs_mount/single_frames/000623',
#  '../../../mnt/nfs_mount/single_frames/000624',
#  '../../../mnt/nfs_mount/single_frames/000625',
#  '../../../mnt/nfs_mount/single_frames/000626',
#  '../../../mnt/nfs_mount/single_frames/000627',
#  '../../../mnt/nfs_mount/single_frames/000628',
#  '../../../mnt/nfs_mount/single_frames/000629',
#  '../../../mnt/nfs_mount/single_frames/000630',
#  '../../../mnt/nfs_mount/single_frames/000631',
#  '../../../mnt/nfs_mount/single_frames/000632',
#  '../../../mnt/nfs_mount/single_frames/000633',
#  '../../../mnt/nfs_mount/single_frames/000634',
#  '../../../mnt/nfs_mount/single_frames/000635',
#  '../../../mnt/nfs_mount/single_frames/000636',
#  '../../../mnt/nfs_mount/single_frames/000637',
#  '../../../mnt/nfs_mount/single_frames/000638',
#  '../../../mnt/nfs_mount/single_frames/000639',
#  '../../../mnt/nfs_mount/single_frames/000640',
#  '../../../mnt/nfs_mount/single_frames/000641',
#  '../../../mnt/nfs_mount/single_frames/000642',
#  '../../../mnt/nfs_mount/single_frames/000643',
#  '../../../mnt/nfs_mount/single_frames/000644',
#  '../../../mnt/nfs_mount/single_frames/000645',
#  '../../../mnt/nfs_mount/single_frames/000646',
#  '../../../mnt/nfs_mount/single_frames/000647',
#  '../../../mnt/nfs_mount/single_frames/000648',
#  '../../../mnt/nfs_mount/single_frames/000649',
#  '../../../mnt/nfs_mount/single_frames/000650',
#  '../../../mnt/nfs_mount/single_frames/000651',
#  '../../../mnt/nfs_mount/single_frames/000652',
#  '../../../mnt/nfs_mount/single_frames/000653',
#  '../../../mnt/nfs_mount/single_frames/000654',
#  '../../../mnt/nfs_mount/single_frames/000655',
#  '../../../mnt/nfs_mount/single_frames/000656',
#  '../../../mnt/nfs_mount/single_frames/000657',
#  '../../../mnt/nfs_mount/single_frames/000658',
#  '../../../mnt/nfs_mount/single_frames/000659',
#  '../../../mnt/nfs_mount/single_frames/000660',
#  '../../../mnt/nfs_mount/single_frames/000661',
#  '../../../mnt/nfs_mount/single_frames/000662',
#  '../../../mnt/nfs_mount/single_frames/000663',
#  '../../../mnt/nfs_mount/single_frames/000664',
#  '../../../mnt/nfs_mount/single_frames/000665',
#  '../../../mnt/nfs_mount/single_frames/000666',
#  '../../../mnt/nfs_mount/single_frames/000667',
#  '../../../mnt/nfs_mount/single_frames/000668',
#  '../../../mnt/nfs_mount/single_frames/000669',
#  '../../../mnt/nfs_mount/single_frames/000670',
#  '../../../mnt/nfs_mount/single_frames/000671',
#  '../../../mnt/nfs_mount/single_frames/000672',
#  '../../../mnt/nfs_mount/single_frames/000673',
#  '../../../mnt/nfs_mount/single_frames/000674',
#  '../../../mnt/nfs_mount/single_frames/000675',
#  '../../../mnt/nfs_mount/single_frames/000676',
#  '../../../mnt/nfs_mount/single_frames/000677',
#  '../../../mnt/nfs_mount/single_frames/000678',
#  '../../../mnt/nfs_mount/single_frames/000679',
#  '../../../mnt/nfs_mount/single_frames/000680',
#  '../../../mnt/nfs_mount/single_frames/000681',
#  '../../../mnt/nfs_mount/single_frames/000682',
#  '../../../mnt/nfs_mount/single_frames/000683',
#  '../../../mnt/nfs_mount/single_frames/000684',
#  '../../../mnt/nfs_mount/single_frames/000685',
#  '../../../mnt/nfs_mount/single_frames/000686',
#  '../../../mnt/nfs_mount/single_frames/000687',
#  '../../../mnt/nfs_mount/single_frames/000688',
#  '../../../mnt/nfs_mount/single_frames/000689',
#  '../../../mnt/nfs_mount/single_frames/000690',
#  '../../../mnt/nfs_mount/single_frames/000691',
#  '../../../mnt/nfs_mount/single_frames/000692',
#  '../../../mnt/nfs_mount/single_frames/000693',
#  '../../../mnt/nfs_mount/single_frames/000694',
#  '../../../mnt/nfs_mount/single_frames/000695',
#  '../../../mnt/nfs_mount/single_frames/000696',
#  '../../../mnt/nfs_mount/single_frames/000697',
#  '../../../mnt/nfs_mount/single_frames/000698',
#  '../../../mnt/nfs_mount/single_frames/000699',
#  '../../../mnt/nfs_mount/single_frames/000700',
#  '../../../mnt/nfs_mount/single_frames/000701',
#  '../../../mnt/nfs_mount/single_frames/000702',
#  '../../../mnt/nfs_mount/single_frames/000703',
#  '../../../mnt/nfs_mount/single_frames/000704',
#  '../../../mnt/nfs_mount/single_frames/000705',
#  '../../../mnt/nfs_mount/single_frames/000706',
#  '../../../mnt/nfs_mount/single_frames/000707',
#  '../../../mnt/nfs_mount/single_frames/000708',
#  '../../../mnt/nfs_mount/single_frames/000709',
#  '../../../mnt/nfs_mount/single_frames/000710',
#  '../../../mnt/nfs_mount/single_frames/000711',
#  '../../../mnt/nfs_mount/single_frames/000712',
#  '../../../mnt/nfs_mount/single_frames/000713',
#  '../../../mnt/nfs_mount/single_frames/000714',
#  '../../../mnt/nfs_mount/single_frames/000715',
#  '../../../mnt/nfs_mount/single_frames/000716',
#  '../../../mnt/nfs_mount/single_frames/000717',
#  '../../../mnt/nfs_mount/single_frames/000718',
#  '../../../mnt/nfs_mount/single_frames/000719',
#  '../../../mnt/nfs_mount/single_frames/000720',
#  '../../../mnt/nfs_mount/single_frames/000721',
#  '../../../mnt/nfs_mount/single_frames/000722',
#  '../../../mnt/nfs_mount/single_frames/000723',
#  '../../../mnt/nfs_mount/single_frames/000724',
#  '../../../mnt/nfs_mount/single_frames/000725',
#  '../../../mnt/nfs_mount/single_frames/000726',
#  '../../../mnt/nfs_mount/single_frames/000727',
#  '../../../mnt/nfs_mount/single_frames/000728',
#  '../../../mnt/nfs_mount/single_frames/000729',
#  '../../../mnt/nfs_mount/single_frames/000730',
#  '../../../mnt/nfs_mount/single_frames/000731',
#  '../../../mnt/nfs_mount/single_frames/000732',
#  '../../../mnt/nfs_mount/single_frames/000733',
#  '../../../mnt/nfs_mount/single_frames/000734',
#  '../../../mnt/nfs_mount/single_frames/000735',
#  '../../../mnt/nfs_mount/single_frames/000736',
#  '../../../mnt/nfs_mount/single_frames/000737',
#  '../../../mnt/nfs_mount/single_frames/000738',
#  '../../../mnt/nfs_mount/single_frames/000739',
#  '../../../mnt/nfs_mount/single_frames/000740',
#  '../../../mnt/nfs_mount/single_frames/000741',
#  '../../../mnt/nfs_mount/single_frames/000742',
#  '../../../mnt/nfs_mount/single_frames/000743',
#  '../../../mnt/nfs_mount/single_frames/000744',
#  '../../../mnt/nfs_mount/single_frames/000745',
#  '../../../mnt/nfs_mount/single_frames/000746',
#  '../../../mnt/nfs_mount/single_frames/000747',
#  '../../../mnt/nfs_mount/single_frames/000748',
#  '../../../mnt/nfs_mount/single_frames/000749',
#  '../../../mnt/nfs_mount/single_frames/000750',
#  '../../../mnt/nfs_mount/single_frames/000751',
#  '../../../mnt/nfs_mount/single_frames/000752',
#  '../../../mnt/nfs_mount/single_frames/000753',
#  '../../../mnt/nfs_mount/single_frames/000754',
#  '../../../mnt/nfs_mount/single_frames/000755',
#  '../../../mnt/nfs_mount/single_frames/000756',
#  '../../../mnt/nfs_mount/single_frames/000757',
#  '../../../mnt/nfs_mount/single_frames/000758',
#  '../../../mnt/nfs_mount/single_frames/000759',
#  '../../../mnt/nfs_mount/single_frames/000760',
#  '../../../mnt/nfs_mount/single_frames/000761',
#  '../../../mnt/nfs_mount/single_frames/000762',
#  '../../../mnt/nfs_mount/single_frames/000763',
#  '../../../mnt/nfs_mount/single_frames/000764',
#  '../../../mnt/nfs_mount/single_frames/000765',
#  '../../../mnt/nfs_mount/single_frames/000766',
#  '../../../mnt/nfs_mount/single_frames/000767',
#  '../../../mnt/nfs_mount/single_frames/000768',
#  '../../../mnt/nfs_mount/single_frames/000769',
#  '../../../mnt/nfs_mount/single_frames/000770',
#  '../../../mnt/nfs_mount/single_frames/000771',
#  '../../../mnt/nfs_mount/single_frames/000772',
#  '../../../mnt/nfs_mount/single_frames/000773',
#  '../../../mnt/nfs_mount/single_frames/000774',
#  '../../../mnt/nfs_mount/single_frames/000775',
#  '../../../mnt/nfs_mount/single_frames/000776',
#  '../../../mnt/nfs_mount/single_frames/000777',
#  '../../../mnt/nfs_mount/single_frames/000778',
#  '../../../mnt/nfs_mount/single_frames/000779',
#  '../../../mnt/nfs_mount/single_frames/000780',
#  '../../../mnt/nfs_mount/single_frames/000781',
#  '../../../mnt/nfs_mount/single_frames/000782',
#  '../../../mnt/nfs_mount/single_frames/000783',
#  '../../../mnt/nfs_mount/single_frames/000784',
#  '../../../mnt/nfs_mount/single_frames/000785',
#  '../../../mnt/nfs_mount/single_frames/000786',
#  '../../../mnt/nfs_mount/single_frames/000787',
#  '../../../mnt/nfs_mount/single_frames/000788',
#  '../../../mnt/nfs_mount/single_frames/000789',
#  '../../../mnt/nfs_mount/single_frames/000790',
#  '../../../mnt/nfs_mount/single_frames/000791',
#  '../../../mnt/nfs_mount/single_frames/000792',
#  '../../../mnt/nfs_mount/single_frames/000793',
#  '../../../mnt/nfs_mount/single_frames/000794',
#  '../../../mnt/nfs_mount/single_frames/000795',
#  '../../../mnt/nfs_mount/single_frames/000796',
#  '../../../mnt/nfs_mount/single_frames/000797',
#  '../../../mnt/nfs_mount/single_frames/000798',
#  '../../../mnt/nfs_mount/single_frames/000799',
#  '../../../mnt/nfs_mount/single_frames/000800',
#  '../../../mnt/nfs_mount/single_frames/000801',
#  '../../../mnt/nfs_mount/single_frames/000802',
#  '../../../mnt/nfs_mount/single_frames/000803',
#  '../../../mnt/nfs_mount/single_frames/000804',
#  '../../../mnt/nfs_mount/single_frames/000805',
#  '../../../mnt/nfs_mount/single_frames/000806',
#  '../../../mnt/nfs_mount/single_frames/000807',
#  '../../../mnt/nfs_mount/single_frames/000808',
#  '../../../mnt/nfs_mount/single_frames/000809',
#  '../../../mnt/nfs_mount/single_frames/000810',
#  '../../../mnt/nfs_mount/single_frames/000811',
#  '../../../mnt/nfs_mount/single_frames/000812',
#  '../../../mnt/nfs_mount/single_frames/000813',
#  '../../../mnt/nfs_mount/single_frames/000814',
#  '../../../mnt/nfs_mount/single_frames/000815',
#  '../../../mnt/nfs_mount/single_frames/000816',
#  '../../../mnt/nfs_mount/single_frames/000817',
#  '../../../mnt/nfs_mount/single_frames/000819',
#  '../../../mnt/nfs_mount/single_frames/000818',
#  '../../../mnt/nfs_mount/single_frames/000820',
#  '../../../mnt/nfs_mount/single_frames/000822',
#  '../../../mnt/nfs_mount/single_frames/000821',
#  '../../../mnt/nfs_mount/single_frames/000824',
#  '../../../mnt/nfs_mount/single_frames/000826',
#  '../../../mnt/nfs_mount/single_frames/000823',
#  '../../../mnt/nfs_mount/single_frames/000827',
#  '../../../mnt/nfs_mount/single_frames/000825',
#  '../../../mnt/nfs_mount/single_frames/000830',
#  '../../../mnt/nfs_mount/single_frames/000831',
#  '../../../mnt/nfs_mount/single_frames/000833',
#  '../../../mnt/nfs_mount/single_frames/000828',
#  '../../../mnt/nfs_mount/single_frames/000834',
#  '../../../mnt/nfs_mount/single_frames/000829',
#  '../../../mnt/nfs_mount/single_frames/000835',
#  '../../../mnt/nfs_mount/single_frames/000837',
#  '../../../mnt/nfs_mount/single_frames/000832',
#  '../../../mnt/nfs_mount/single_frames/000839',
#  '../../../mnt/nfs_mount/single_frames/000841',
#  '../../../mnt/nfs_mount/single_frames/000842',
#  '../../../mnt/nfs_mount/single_frames/000836',
#  '../../../mnt/nfs_mount/single_frames/000843',
#  '../../../mnt/nfs_mount/single_frames/000844',
#  '../../../mnt/nfs_mount/single_frames/000838',
#  '../../../mnt/nfs_mount/single_frames/000845',
#  '../../../mnt/nfs_mount/single_frames/000846',
#  '../../../mnt/nfs_mount/single_frames/000840',
#  '../../../mnt/nfs_mount/single_frames/000848',
#  '../../../mnt/nfs_mount/single_frames/000850',
#  '../../../mnt/nfs_mount/single_frames/000851',
#  '../../../mnt/nfs_mount/single_frames/000852',
#  '../../../mnt/nfs_mount/single_frames/000853',
#  '../../../mnt/nfs_mount/single_frames/000847',
#  '../../../mnt/nfs_mount/single_frames/000854',
#  '../../../mnt/nfs_mount/single_frames/000856',
#  '../../../mnt/nfs_mount/single_frames/000849',
#  '../../../mnt/nfs_mount/single_frames/000858',
#  '../../../mnt/nfs_mount/single_frames/000859',
#  '../../../mnt/nfs_mount/single_frames/000862',
#  '../../../mnt/nfs_mount/single_frames/000863',
#  '../../../mnt/nfs_mount/single_frames/000864',
#  '../../../mnt/nfs_mount/single_frames/000855',
#  '../../../mnt/nfs_mount/single_frames/000865',
#  '../../../mnt/nfs_mount/single_frames/000866',
#  '../../../mnt/nfs_mount/single_frames/000857',
#  '../../../mnt/nfs_mount/single_frames/000867',
#  '../../../mnt/nfs_mount/single_frames/000868',
#  '../../../mnt/nfs_mount/single_frames/000860',
#  '../../../mnt/nfs_mount/single_frames/000870',
#  '../../../mnt/nfs_mount/single_frames/000861',
#  '../../../mnt/nfs_mount/single_frames/000871',
#  '../../../mnt/nfs_mount/single_frames/000872',
#  '../../../mnt/nfs_mount/single_frames/000873',
#  '../../../mnt/nfs_mount/single_frames/000874',
#  '../../../mnt/nfs_mount/single_frames/000876',
#  '../../../mnt/nfs_mount/single_frames/000877',
#  '../../../mnt/nfs_mount/single_frames/000869',
#  '../../../mnt/nfs_mount/single_frames/000878',
#  '../../../mnt/nfs_mount/single_frames/000879',
#  '../../../mnt/nfs_mount/single_frames/000880',
#  '../../../mnt/nfs_mount/single_frames/000881',
#  '../../../mnt/nfs_mount/single_frames/000882',
#  '../../../mnt/nfs_mount/single_frames/000875',
#  '../../../mnt/nfs_mount/single_frames/000883',
#  '../../../mnt/nfs_mount/single_frames/000885',
#  '../../../mnt/nfs_mount/single_frames/000886',
#  '../../../mnt/nfs_mount/single_frames/000887',
#  '../../../mnt/nfs_mount/single_frames/000890',
#  '../../../mnt/nfs_mount/single_frames/000891',
#  '../../../mnt/nfs_mount/single_frames/000892',
#  '../../../mnt/nfs_mount/single_frames/000884',
#  '../../../mnt/nfs_mount/single_frames/000894',
#  '../../../mnt/nfs_mount/single_frames/000895',
#  '../../../mnt/nfs_mount/single_frames/000896',
#  '../../../mnt/nfs_mount/single_frames/000897',
#  '../../../mnt/nfs_mount/single_frames/000888',
#  '../../../mnt/nfs_mount/single_frames/000899',
#  '../../../mnt/nfs_mount/single_frames/000889',
#  '../../../mnt/nfs_mount/single_frames/000900',
#  '../../../mnt/nfs_mount/single_frames/000901',
#  '../../../mnt/nfs_mount/single_frames/000903',
#  '../../../mnt/nfs_mount/single_frames/000893',
#  '../../../mnt/nfs_mount/single_frames/000905',
#  '../../../mnt/nfs_mount/single_frames/000907',
#  '../../../mnt/nfs_mount/single_frames/000908',
#  '../../../mnt/nfs_mount/single_frames/000909',
#  '../../../mnt/nfs_mount/single_frames/000898',
#  '../../../mnt/nfs_mount/single_frames/000910',
#  '../../../mnt/nfs_mount/single_frames/000911',
#  '../../../mnt/nfs_mount/single_frames/000913',
#  '../../../mnt/nfs_mount/single_frames/000902',
#  '../../../mnt/nfs_mount/single_frames/000914',
#  '../../../mnt/nfs_mount/single_frames/000915',
#  '../../../mnt/nfs_mount/single_frames/000904',
#  '../../../mnt/nfs_mount/single_frames/000917',
#  '../../../mnt/nfs_mount/single_frames/000918',
#  '../../../mnt/nfs_mount/single_frames/000906',
#  '../../../mnt/nfs_mount/single_frames/000919',
#  '../../../mnt/nfs_mount/single_frames/000920',
#  '../../../mnt/nfs_mount/single_frames/000921',
#  '../../../mnt/nfs_mount/single_frames/000922',
#  '../../../mnt/nfs_mount/single_frames/000923',
#  '../../../mnt/nfs_mount/single_frames/000912',
#  '../../../mnt/nfs_mount/single_frames/000924',
#  '../../../mnt/nfs_mount/single_frames/000925',
#  '../../../mnt/nfs_mount/single_frames/000926',
#  '../../../mnt/nfs_mount/single_frames/000927',
#  '../../../mnt/nfs_mount/single_frames/000916',
#  '../../../mnt/nfs_mount/single_frames/000928',
#  '../../../mnt/nfs_mount/single_frames/000929',
#  '../../../mnt/nfs_mount/single_frames/000930',
#  '../../../mnt/nfs_mount/single_frames/000931',
#  '../../../mnt/nfs_mount/single_frames/000933',
#  '../../../mnt/nfs_mount/single_frames/000934',
#  '../../../mnt/nfs_mount/single_frames/000935',
#  '../../../mnt/nfs_mount/single_frames/000936',
#  '../../../mnt/nfs_mount/single_frames/000937',
#  '../../../mnt/nfs_mount/single_frames/000938',
#  '../../../mnt/nfs_mount/single_frames/000940',
#  '../../../mnt/nfs_mount/single_frames/000944',
#  '../../../mnt/nfs_mount/single_frames/000932',
#  '../../../mnt/nfs_mount/single_frames/000945',
#  '../../../mnt/nfs_mount/single_frames/000946',
#  '../../../mnt/nfs_mount/single_frames/000948',
#  '../../../mnt/nfs_mount/single_frames/000949',
#  '../../../mnt/nfs_mount/single_frames/000950',
#  '../../../mnt/nfs_mount/single_frames/000952',
#  '../../../mnt/nfs_mount/single_frames/000939',
#  '../../../mnt/nfs_mount/single_frames/000955',
#  '../../../mnt/nfs_mount/single_frames/000956',
#  '../../../mnt/nfs_mount/single_frames/000941',
#  '../../../mnt/nfs_mount/single_frames/000957',
#  '../../../mnt/nfs_mount/single_frames/000942',
#  '../../../mnt/nfs_mount/single_frames/000959',
#  '../../../mnt/nfs_mount/single_frames/000943',
#  '../../../mnt/nfs_mount/single_frames/000963',
#  '../../../mnt/nfs_mount/single_frames/000966',
#  '../../../mnt/nfs_mount/single_frames/000967',
#  '../../../mnt/nfs_mount/single_frames/000947',
#  '../../../mnt/nfs_mount/single_frames/000968',
#  '../../../mnt/nfs_mount/single_frames/000969',
#  '../../../mnt/nfs_mount/single_frames/000970',
#  '../../../mnt/nfs_mount/single_frames/000971',
#  '../../../mnt/nfs_mount/single_frames/000951',
#  '../../../mnt/nfs_mount/single_frames/000972',
#  '../../../mnt/nfs_mount/single_frames/000973',
#  '../../../mnt/nfs_mount/single_frames/000953',
#  '../../../mnt/nfs_mount/single_frames/000974',
#  '../../../mnt/nfs_mount/single_frames/000954',
#  '../../../mnt/nfs_mount/single_frames/000975',
#  '../../../mnt/nfs_mount/single_frames/000979',
#  '../../../mnt/nfs_mount/single_frames/000980',
#  '../../../mnt/nfs_mount/single_frames/000958',
#  '../../../mnt/nfs_mount/single_frames/000981',
#  '../../../mnt/nfs_mount/single_frames/000960',
#  '../../../mnt/nfs_mount/single_frames/000982',
#  '../../../mnt/nfs_mount/single_frames/000961',
#  '../../../mnt/nfs_mount/single_frames/000983',
#  '../../../mnt/nfs_mount/single_frames/000962',
#  '../../../mnt/nfs_mount/single_frames/000984',
#  '../../../mnt/nfs_mount/single_frames/000985',
#  '../../../mnt/nfs_mount/single_frames/000964',
#  '../../../mnt/nfs_mount/single_frames/000986',
#  '../../../mnt/nfs_mount/single_frames/000965',
#  '../../../mnt/nfs_mount/single_frames/000987',
#  '../../../mnt/nfs_mount/single_frames/000988',
#  '../../../mnt/nfs_mount/single_frames/000989',
#  '../../../mnt/nfs_mount/single_frames/000991',
#  '../../../mnt/nfs_mount/single_frames/000992',
#  '../../../mnt/nfs_mount/single_frames/000994',
#  '../../../mnt/nfs_mount/single_frames/000997',
#  '../../../mnt/nfs_mount/single_frames/000998',
#  '../../../mnt/nfs_mount/single_frames/000999',
#  '../../../mnt/nfs_mount/single_frames/000976',
#  '../../../mnt/nfs_mount/single_frames/001001',
#  '../../../mnt/nfs_mount/single_frames/000977',
#  '../../../mnt/nfs_mount/single_frames/001003',
#  '../../../mnt/nfs_mount/single_frames/000978',
#  '../../../mnt/nfs_mount/single_frames/001004',
#  '../../../mnt/nfs_mount/single_frames/001005',
#  ...]

# %%
server = Server(num_clients=5, output_path="", num_rounds=5, 
                local_epochs=5, batch_size=32)
server

# %%
server.setup()
# Out:
# [<torch.utils.data.dataloader.DataLoader object at 0x7f8b812fd450>, <torch.utils.data.dataloader.DataLoader object at 0x7f8b812fd5a0>, <torch.utils.data.dataloader.DataLoader object at 0x7f8b812fd6f0>, <torch.utils.data.dataloader.DataLoader object at 0x7f8b812fd840>, <torch.utils.data.dataloader.DataLoader object at 0x7f8b812fd990>]

# %%
server.send_model()

# %%
# server.clients[0].model

# %%
server.clients[0].dataloader

# %%
server.clients[0].client_update()
# Out:
# Epoch 1/5: 0it [00:00, ?it/s]     | 0/5 [00:00<?, ?it/s]
# Epoch 2/5: 0it [00:00, ?it/s]     | 0/5 [00:00<?, ?it/s, epoch=0]
# Epoch 3/5: 0it [00:00, ?it/s]     | 0/5 [00:00<?, ?it/s, epoch=1]
# Epoch 4/5: 0it [00:00, ?it/s]     | 0/5 [00:00<?, ?it/s, epoch=2]
# Epoch 5/5: 0it [00:00, ?it/s]     | 0/5 [00:00<?, ?it/s, epoch=3]
# Training client 1: 100%|██████████| 5/5 [00:00<00:00, 254.39it/s, epoch=4]
# last learning rate:  0.0075

# %%
for idx, data in enumerate(server.clients[0].dataloader):
    images = data[0]
    print(images)
    image = images[0][0]
    views = images[1]

# %%
server.clients[0].dataloader

# %%
class ZenseactSSLDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = data
        self.transform = transform

    def __getitem__(self, idx):
        dat = self.data[idx]
        if self.transform:
            dat = self.transform[dat]
        dummy_label = 0
        return dat, dummy_label

    def __len__(self):
        return len(self.data)
    
class TwoCropsTransform:
    """Take two random crops of one image as the query and key."""

    def __init__(self, base_transform, num_views):
        self.base_transform = base_transform
        self.num_views = num_views

    def __call__(self, x):
        q = [self.base_transform(x)]
        views = []
        for view in range(self.num_views):
            view = self.base_transform(x)
            views.append(view)
        # q = q.extend(views)
        return [q, views]

# %%
def generate_ssl_data(size=50_000):
    parent_directory = "../../../mnt/nfs_mount/single_frames"

    # Find all folders with a 6-digit name
    folder_pattern = os.path.join(parent_directory, "[0-9]" * 6)

    # Get the list of matching folders
    folders = glob.glob(folder_pattern)
    folders = folders[0:size] # *size* folders

    image_data = []
    for folder in folders:
        id = os.path.basename(folder) # id = foldername
        # load image
        image_path = f"../../../mnt/nfs_mount/single_frames/{id}/camera_front_blur/"
        image_path = glob.glob(image_path + "*.jpg")
        image = Image.open(image_path[0]).convert('RGB')
        # resize image
        downsampled_image = image.resize(RESCALE_SIZE)

        image_data.append(downsampled_image)
    return image_data
# Out:
# [<PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>,
#  <PIL.Image.Image image mode=RGB size=120x100>]

# %%
ZenseactSSLDataset(image_data)

# %%
class ZenseactDataset(Dataset):
    def __init__(self, size=50_000, transform=None):
        self.image_paths = []
        self.transform = transform

        # The parent directory containing the folders
        parent_directory = "../../../mnt/nfs_mount/single_frames"

        # Find all folders with a 6-digit name
        folder_pattern = os.path.join(parent_directory, "[0-9]" * 6)

        # Get the list of matching folders
        folders = glob.glob(folder_pattern)
        self.folders = folders[0:size] # *size* folders

        for folder in self.folders:
            id = os.path.basename(folder) # id = foldername
            # load image
            image_path = f"../../../mnt/nfs_mount/single_frames/{id}/camera_front_blur/"
            image_path = glob.glob(image_path + "*.jpg")
            self.image_paths.append(image_path)


    def __len__(self):
        return len(self.folders)


    def __getitem__(self, idx):
        image_path = self.image_paths[idx][0]
        # load image
        image = Image.open(image_path).convert('RGB')
        # resize image
        downsampled_image = image.resize(RESCALE_SIZE)

        if self.transform:
            downsampled_image = self.transform(downsampled_image)

        dummy_label = 0        
        return downsampled_image, dummy_label
    

class TwoCropsTransform:
    """Take two random crops of one image as the query and key."""

    def __init__(self, base_transform, num_views):
        self.base_transform = base_transform
        self.num_views = num_views

    def __call__(self, x):
        q = [self.base_transform(x)]
        views = []
        for view in range(self.num_views):
            view = self.base_transform(x)
            views.append(view)
        # q = q.extend(views)
        return [q, views]
